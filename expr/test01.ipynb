# %%
import matplotlib.pyplot as plt
import math
import numpy as np

np.random.seed(1)

# %%
# generate data
x = np.arange(0, 30)
y = np.sin(x) + np.random.rand(len(x))

# %%
plt.plot(x, y)

# %%
b = [1,1,2,3,4,5,2,1,1,1,2,4,5,6,3,2,1,1,1,3,5,6,4,3,2,1]
